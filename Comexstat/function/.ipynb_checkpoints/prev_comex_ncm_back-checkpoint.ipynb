# %%
from sklearn.ensemble import RandomForestClassifier as RFC_
from sklearn.ensemble import RandomForestRegressor as RFR_
import seaborn as sns

# %%
import time
ini_time=time.time()

import datetime

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np




#%run 'prev_comex_ncm.ipynb'

# Define parametros
cat_cols=['CO_MES','nick','SG_UF_NCM','CO_PAIS','CO_URF']
l=20

comex_ncm=pd.read_csv('~/git/BD/temp/imp_fert_quanti.csv').sort_values(by=['CO_ANO','CO_MES'])

# Filtra top
top_nick=comex_ncm.groupby('nick').KG_LIQUIDO.sum().sort_values().index[-2:]
top_uf=comex_ncm.groupby('SG_UF_NCM').KG_LIQUIDO.sum().sort_values().index[-2:]
top_pais=comex_ncm.groupby('CO_PAIS').KG_LIQUIDO.sum().sort_values().index[-2:]
top_urf=comex_ncm.groupby('CO_URF').KG_LIQUIDO.sum().sort_values().index[-2:]
comex_ncm=comex_ncm[comex_ncm.SG_UF_NCM.isin(top_uf)]
comex_ncm=comex_ncm[(comex_ncm.nick.isin(top_nick))]
comex_ncm=comex_ncm[comex_ncm.CO_URF.isin(top_urf)]
comex_ncm=comex_ncm[comex_ncm.CO_PAIS.isin(top_pais)]

# Salva datas de início e fim
comex_ncm['date']=pd.to_datetime(comex_ncm.CO_ANO.astype(str)+'/'+comex_ncm.CO_MES.astype(str)+'/1')
date_ini=comex_ncm.date.min()
date_fim=comex_ncm.date.max()

# %%
sns.relplot(data=comex_ncm,x='date',y='KG_LIQUIDO',col='nick')

# %%
comex_ncm=comex_ncm[comex_ncm.CO_ANO>2008]

# %%
comex_ncm.to_csv('comex_ncm_base_pred.csv',index=False)

# %%
# Sparse Matrix 
# Matriz 1
anos=pd.DataFrame({'CO_ANO':np.arange(comex_ncm.CO_ANO.max(),comex_ncm.CO_ANO.max()+1),'key':0})
# Matriz 2
cat=comex_ncm[cat_cols].drop_duplicates().assign(key=0)
# Multiplica
c_c=anos.merge(cat,how='outer').drop(columns='key')        
comex_ncm=c_c.merge(comex_ncm,how='outer').fillna(0)
# Refaz data
comex_ncm['date']=pd.to_datetime(comex_ncm.CO_ANO.astype(str)+'/'+comex_ncm.CO_MES.astype(str)+'/1')
# Apara as bordas
comex_ncm=comex_ncm[(comex_ncm.date<=date_fim)&(comex_ncm.date>=date_ini)]

# %%
comex_ncm
# Out:
#      CO_ANO  CO_MES     nick SG_UF_NCM  CO_PAIS  CO_URF  KG_LIQUIDO       date
# 0      2009       2  UREIA_k        PR      676  917800   2000000.0 2009-02-01
# 1      2009       3  UREIA_k        PR      999  917800   4013177.0 2009-03-01
# 2      2009       4  UREIA_k        PR      676  917800   2500000.0 2009-04-01
# 3      2009       5  UREIA_k        PR      676  917800   8000000.0 2009-05-01
# 4      2009       6    MOP_k        PR      676  917800  18150000.0 2009-06-01
# ..      ...     ...      ...       ...      ...     ...         ...        ...
# 530    2024       4  UREIA_k        PR      676  817800         0.0 2024-04-01
# 531    2024       4  UREIA_k        PR      676  917800   6524000.0 2024-04-01
# 532    2024       4  UREIA_k        PR      999  917800  22839957.0 2024-04-01
# 533    2024       4  UREIA_k        RS      676  917800         0.0 2024-04-01
# 534    2024       4  UREIA_k        RS      999  917800    800000.0 2024-04-01
#
# [535 rows x 8 columns]

# %%
comex_ncm.date.min
# Out:
# <bound method Series.min of 0     2009-02-01
# 1     2009-03-01
# 2     2009-04-01
# 3     2009-05-01
# 4     2009-06-01
#          ...
# 530   2024-04-01
# 531   2024-04-01
# 532   2024-04-01
# 533   2024-04-01
# 534   2024-04-01
# Name: date, Length: 535, dtype: datetime64[ns]>

# %%
target_cols=['oc','KG_LIQUIDO']
cat_cols=['CO_MES','nick','SG_UF_NCM','CO_PAIS','CO_URF']
md_c=15
md_r=1

# Identifica as datas de previsao
pred_max=comex_ncm.date.max()
pred_min=comex_ncm.date.min()
# Classificação ##########################################################################################

# Marca ocorrências
comex_ncm=comex_ncm.assign(oc=0)
comex_ncm.loc[comex_ncm[target_cols[1]]>0,'oc']=1
comex_ncm
# Out:
#      CO_ANO  CO_MES     nick SG_UF_NCM  CO_PAIS  CO_URF  KG_LIQUIDO  \
# 0      2009       2  UREIA_k        PR      676  917800   2000000.0
# 1      2009       3  UREIA_k        PR      999  917800   4013177.0
# 2      2009       4  UREIA_k        PR      676  917800   2500000.0
# 3      2009       5  UREIA_k        PR      676  917800   8000000.0
# 4      2009       6    MOP_k        PR      676  917800  18150000.0
# ..      ...     ...      ...       ...      ...     ...         ...
# 530    2024       4  UREIA_k        PR      676  817800         0.0
# 531    2024       4  UREIA_k        PR      676  917800   6524000.0
# 532    2024       4  UREIA_k        PR      999  917800  22839957.0
# 533    2024       4  UREIA_k        RS      676  917800         0.0
# 534    2024       4  UREIA_k        RS      999  917800    800000.0
#
#           date  oc
# 0   2009-02-01   1
# 1   2009-03-01   1
# 2   2009-04-01   1
# 3   2009-05-01   1
# 4   2009-06-01   1
# ..         ...  ..
# 530 2024-04-01   0
# 531 2024-04-01   1
# 532 2024-04-01   1
# 533 2024-04-01   0
# 534 2024-04-01   1
#
# [535 rows x 9 columns]

# %%
# Codifica categorias
comex_ncm[cat_cols]=comex_ncm[cat_cols].astype('category')    
comex_ncm_dumm=pd.get_dummies(comex_ncm, prefix_sep='~')

# Data em formato para processamento
comex_ncm_dumm.date=comex_ncm_dumm.date.astype(int)
# Ano substituido por date, que da a sequencia dos meses
comex_ncm_dumm.drop(columns='CO_ANO',inplace=True)

comex_ncm_dumm
# Out:
#      KG_LIQUIDO                 date  oc  CO_MES~1  CO_MES~2  CO_MES~3  \
# 0     2000000.0  1233446400000000000   1     False      True     False
# 1     4013177.0  1235865600000000000   1     False     False      True
# 2     2500000.0  1238544000000000000   1     False     False     False
# 3     8000000.0  1241136000000000000   1     False     False     False
# 4    18150000.0  1243814400000000000   1     False     False     False
# ..          ...                  ...  ..       ...       ...       ...
# 530         0.0  1711929600000000000   0     False     False     False
# 531   6524000.0  1711929600000000000   1     False     False     False
# 532  22839957.0  1711929600000000000   1     False     False     False
# 533         0.0  1711929600000000000   0     False     False     False
# 534    800000.0  1711929600000000000   1     False     False     False
#
#      CO_MES~4  CO_MES~5  CO_MES~6  CO_MES~7  ...  CO_MES~11  CO_MES~12  \
# 0       False     False     False     False  ...      False      False
# 1       False     False     False     False  ...      False      False
# 2        True     False     False     False  ...      False      False
# 3       False      True     False     False  ...      False      False
# 4       False     False      True     False  ...      False      False
# ..        ...       ...       ...       ...  ...        ...        ...
# 530      True     False     False     False  ...      False      False
# 531      True     False     False     False  ...      False      False
# 532      True     False     False     False  ...      False      False
# 533      True     False     False     False  ...      False      False
# 534      True     False     False     False  ...      False      False
#
#      nick~MOP_k  nick~UREIA_k  SG_UF_NCM~PR  SG_UF_NCM~RS  CO_PAIS~676  \
# 0         False          True          True         False         True
# 1         False          True          True         False        False
# 2         False          True          True         False         True
# 3         False          True          True         False         True
# 4          True         False          True         False         True
# ..          ...           ...           ...           ...          ...
# 530       False          True          True         False         True
# 531       False          True          True         False         True
# 532       False          True          True         False        False
# 533       False          True         False          True         True
# 534       False          True         False          True        False
#
#      CO_PAIS~999  CO_URF~817800  CO_URF~917800
# 0          False          False           True
# 1           True          False           True
# 2          False          False           True
# 3          False          False           True
# 4          False          False           True
# ..           ...            ...            ...
# 530        False           True          False
# 531        False          False           True
# 532         True          False           True
# 533        False          False           True
# 534         True          False           True
#
# [535 rows x 23 columns]

# %%
pred_min
# Out:
# Timestamp('2009-02-01 00:00:00')

# %%
pred_max
# Out:
# Timestamp('2024-04-01 00:00:00')

# %%
pred_min
# Out:
# Timestamp('2009-02-01 00:00:00')

# %%
# Separa train, test_max e test_max
def train_test_max_test_min(df, pred_max, pred_min):
    '''Identifica train, test_max, test_min'''
    
    train=df[(df.date.astype('datetime64[ns]')>pred_min)&(df.date.astype('datetime64[ns]')<pred_max)]
    # Identifica test na data mínima e máxima
    test_max=df[df.date.astype('datetime64[ns]')==pred_max]
    test_min=df[df.date.astype('datetime64[ns]')==pred_min]    
    return [train,test_max,test_min]
[train_c,test_max_c,test_min_c]=train_test_max_test_min(comex_ncm_dumm,pred_max, pred_min)

# %%
# Separa em X e y
def Xy(train,test_max, test_min, col_target,col_del):
    X_train=train.drop(columns=[col_target]+[col_del])
    y_train=train[col_target]
    X_test_max=test_max.drop(columns=[col_target]+[col_del])
    y_test_max=test_max[col_target]
    X_test_min=test_min.drop(columns=[col_target]+[col_del])
    y_test_min=test_min[col_target]
    return [X_train,y_train,X_test_max,y_test_max,X_test_min,y_test_min]

[X_train_c,y_train_c,X_test_max_c,y_test_max_c,X_test_min_c,y_test_min_c]=Xy(train_c,test_max_c,test_min_c,target_cols[0],target_cols[1])
# Prediz

# %%
def fit_pred(RF,md,X_train,y_train,X_test_max,y_test_max,X_test_min,y_test_min, col_target):
    # Fit
    RF=RF(max_depth=md)
    RF.fit(X_train,y_train)

    # Prediz Max
    test_pred_max=X_test_max.assign(col1=RF.predict(X_test_max)).rename(columns={'col1':str(col_target)+'_pred'})
    test_pred_max=test_pred_max.assign(col2=y_test_max).rename(columns={'col2':(str(col_target))})

    # Prediz min
    test_pred_min=X_test_min.assign(col1=RF.predict(X_test_min)).rename(columns={'col1':str(col_target)+'_pred'})
    test_pred_min=test_pred_min.assign(col2=y_test_min).rename(columns={'col2':(str(col_target))})

    return [test_pred_max,test_pred_min]

# %%
list_test_pred_c=fit_pred(RFC_,md_c,X_train_c,y_train_c,X_test_max_c,y_test_max_c,X_test_min_c,y_test_min_c,target_cols[0])

test_pred_max_c,test_pred_min_c=list_test_pred_c

# %%
# Regressão ##########################################################################################

# Filtra deixando passar somente ocorridos e previstos de ocorrer
train_r=train_c[train_c.oc==1]
test_max_r=test_pred_max_c[(test_pred_max_c.oc==1)&(test_pred_max_c.oc_pred==1)]
test_max_r=test_pred_min_c[(test_pred_min_c.oc==1)&(test_pred_min_c.oc_pred==1)]

# %%
#if (len(train_r)>0) & ((len(test_max_r)>0) | (len(test_max_r)>0)):

# Filtra deixando passar para o treino somente combinacoes categoricas presentes na predicao
def decode(df):
    df=pd.concat([
    df.select_dtypes(exclude='bool'),
    pd.from_dummies(df.select_dtypes(include='bool'),sep='~')],axis=1)
    return df
train_r=decode(train_r)
test_max_r=decode(test_max_r)
test_max_r=decode(test_max_r)

# %%
filtro=pd.concat([test_max_r,test_max_r])[cat_cols].drop_duplicates()
train_r=train_r.merge(filtro)
train_r.head(1)
# Out:
#    KG_LIQUIDO                 date  oc CO_MES     nick SG_UF_NCM CO_PAIS  \
# 0   3812000.0  1264982400000000000   1      2  UREIA_k        PR     676
#
#    CO_URF
# 0  917800

# %%
comex_ncm.date=comex_ncm.date.astype('int')
test_max_r=test_max_r.merge(comex_ncm)
test_max_r=test_max_r.merge(comex_ncm)

# %%
test_max_r
# Out:
# Empty DataFrame
# Columns: [date, oc_pred, oc, CO_MES, nick, SG_UF_NCM, CO_PAIS, CO_URF, CO_ANO, KG_LIQUIDO]
# Index: []

# %%
comex_ncm_r=pd.concat([train_r,test_max_r,test_max_r])

# %%
# Codifica categorias
comex_ncm[cat_cols]=comex_ncm[cat_cols].astype('category')    
comex_ncm_dumm=pd.get_dummies(comex_ncm, prefix_sep='~')

comex_ncm_dumm.date=comex_ncm_dumm.date.astype(int)

# %%
# Separa train and tests
[train_r,test_max_r,test_min_r]=train_test_max_test_min(comex_ncm_dumm,pred_max, pred_min)

# %%
decode(test_min_r)
# Out:
#    CO_ANO  KG_LIQUIDO                 date  oc CO_MES     nick SG_UF_NCM  \
# 0    2009   2000000.0  1233446400000000000   1      2  UREIA_k        PR
#
#   CO_PAIS  CO_URF
# 0     676  917800

# %%
# Separa X e y
[X_train_r,y_train_r,X_test_max_r,y_test_max_r,X_test_min_r,y_test_min_r]=Xy(train_r,test_max_r,test_min_r,target_cols[1],target_cols[0])

# %%
decode(X_test_min_r)
# Out:
#    CO_ANO                 date CO_MES     nick SG_UF_NCM CO_PAIS  CO_URF
# 0    2009  1233446400000000000      2  UREIA_k        PR     676  917800

# %%
# Prediz
list_test_pred_r=fit_pred(RFR_,md_r,X_train_r,y_train_r,X_test_max_r,y_test_max_r,X_test_min_r,y_test_min_r,target_cols[1])

# %%
list_test_pred_r
# Out:
# [     CO_ANO                 date  CO_MES~1  CO_MES~2  CO_MES~3  CO_MES~4  \
#  528    2024  1711929600000000000     False     False     False      True
#  529    2024  1711929600000000000     False     False     False      True
#  530    2024  1711929600000000000     False     False     False      True
#  531    2024  1711929600000000000     False     False     False      True
#  532    2024  1711929600000000000     False     False     False      True
#  533    2024  1711929600000000000     False     False     False      True
#  534    2024  1711929600000000000     False     False     False      True
#
#       CO_MES~5  CO_MES~6  CO_MES~7  CO_MES~8  ...  nick~MOP_k  nick~UREIA_k  \
#  528     False     False     False     False  ...        True         False
#  529     False     False     False     False  ...        True         False
#  530     False     False     False     False  ...       False          True
#  531     False     False     False     False  ...       False          True
#  532     False     False     False     False  ...       False          True
#  533     False     False     False     False  ...       False          True
#  534     False     False     False     False  ...       False          True
#
#       SG_UF_NCM~PR  SG_UF_NCM~RS  CO_PAIS~676  CO_PAIS~999  CO_URF~817800  \
#  528          True         False         True        False          False
#  529          True         False        False         True          False
#  530          True         False         True        False           True
#  531          True         False         True        False          False
#  532          True         False        False         True          False
#  533         False          True         True        False          False
#  534         False          True        False         True          False
#
#       CO_URF~917800  KG_LIQUIDO_pred  KG_LIQUIDO
#  528           True     2.537542e+07  52606851.0
#  529           True     2.537542e+07  16800000.0
#  530          False     1.857332e+07         0.0
#  531           True     1.857332e+07   6524000.0
#  532           True     1.857332e+07  22839957.0
#  533           True     1.276991e+07         0.0
#  534           True     1.276991e+07    800000.0
#
#  [7 rows x 24 columns],
#     CO_ANO                 date  CO_MES~1  CO_MES~2  CO_MES~3  CO_MES~4  \
#  0    2009  1233446400000000000     False      True     False     False
#
#     CO_MES~5  CO_MES~6  CO_MES~7  CO_MES~8  ...  nick~MOP_k  nick~UREIA_k  \
#  0     False     False     False     False  ...       False          True
#
#     SG_UF_NCM~PR  SG_UF_NCM~RS  CO_PAIS~676  CO_PAIS~999  CO_URF~817800  \
#  0          True         False         True        False          False
#
#     CO_URF~917800  KG_LIQUIDO_pred  KG_LIQUIDO
#  0           True     1.857332e+07   2000000.0
#
#  [1 rows x 24 columns]]

# %%
test_pred_max_r,test_pred_min_r=list_test_pred_r

# %%
decode(test_pred_min_r)
# Out:
#    CO_ANO                 date  KG_LIQUIDO_pred  KG_LIQUIDO CO_MES     nick  \
# 0    2009  1233446400000000000     1.857332e+07   2000000.0      2  UREIA_k
#
#   SG_UF_NCM CO_PAIS  CO_URF
# 0        PR     676  917800

# %%
#else:
#    test_pred_max_r,test_pred_max_r=pd.DataFrame(), pd.DataFrame()

# Junta classi e regress resultados
test_pred_c=pd.concat([test_pred_max_c,test_pred_min_c])
test_pred_r=pd.concat([test_pred_max_r,test_pred_min_r])

# %%
decode(test_pred_r).reset_index(drop=True)
# Out:
#    CO_ANO                 date  KG_LIQUIDO_pred  KG_LIQUIDO CO_MES     nick  \
# 0    2024  1711929600000000000     2.537542e+07  52606851.0      4    MOP_k
# 1    2024  1711929600000000000     2.537542e+07  16800000.0      4    MOP_k
# 2    2024  1711929600000000000     1.857332e+07         0.0      4  UREIA_k
# 3    2024  1711929600000000000     1.857332e+07   6524000.0      4  UREIA_k
# 4    2024  1711929600000000000     1.857332e+07  22839957.0      4  UREIA_k
# 5    2024  1711929600000000000     1.276991e+07         0.0      4  UREIA_k
# 6    2024  1711929600000000000     1.276991e+07    800000.0      4  UREIA_k
# 7    2009  1233446400000000000     1.857332e+07   2000000.0      2  UREIA_k
#
#   SG_UF_NCM CO_PAIS  CO_URF
# 0        PR     676  917800
# 1        PR     999  917800
# 2        PR     676  817800
# 3        PR     676  917800
# 4        PR     999  917800
# 5        RS     676  917800
# 6        RS     999  917800
# 7        PR     676  917800

# %%
test_pred=test_pred_c.merge(test_pred_r)

# %%
test_pred=decode(test_pred)
                     
test_pred
# Out:
#                   date  oc_pred  oc  CO_ANO  KG_LIQUIDO_pred  KG_LIQUIDO  \
# 0  1711929600000000000        1   1    2024     2.537542e+07  52606851.0
# 1  1711929600000000000        1   1    2024     2.537542e+07  16800000.0
# 2  1711929600000000000        0   0    2024     1.857332e+07         0.0
# 3  1711929600000000000        1   1    2024     1.857332e+07   6524000.0
# 4  1711929600000000000        1   1    2024     1.857332e+07  22839957.0
# 5  1711929600000000000        1   0    2024     1.276991e+07         0.0
# 6  1711929600000000000        1   1    2024     1.276991e+07    800000.0
# 7  1233446400000000000        1   1    2009     1.857332e+07   2000000.0
#
#   CO_MES     nick SG_UF_NCM CO_PAIS  CO_URF
# 0      4    MOP_k        PR     676  917800
# 1      4    MOP_k        PR     999  917800
# 2      4  UREIA_k        PR     676  817800
# 3      4  UREIA_k        PR     676  917800
# 4      4  UREIA_k        PR     999  917800
# 5      4  UREIA_k        RS     676  917800
# 6      4  UREIA_k        RS     999  917800
# 7      2  UREIA_k        PR     676  917800

# %%
print("preve_comex_ncm(comex_ncm,target_cols=['oc','KG_LIQUIDO'],cat_cols=['CO_MES','nick','SG_UF_NCM','CO_PAIS','CO_URF'],md_c=15,md_r=1):")
# Out:
# preve_comex_ncm(comex_ncm,target_cols=['oc','KG_LIQUIDO'],cat_cols=['CO_MES','nick','SG_UF_NCM','CO_PAIS','CO_URF'],md_c=15,md_r=1):

# %%
print("RandomForestClassifier as RFC_ & RandomForestRegressor as RFR_")
# Out:
# RandomForestClassifier as RFC_ & RandomForestRegressor as RFR_

# %%
test_pred.to_csv('test_pred.csv',index=False)
